# %%
import os
import re

import pandas as pd
import numpy as np
import unicodedata
import matplotlib.pyplot as plt

import collections
import wordcloud as wc

import nltk

from sklearn.feature_extraction.text import CountVectorizer

# %%
input_path = "data/cdiscount_train.csv.zip"
nb_line=100000  # part totale extraite du fichier initial ici déjà réduit
data_all = pd.read_csv(input_path, sep=",", nrows=nb_line)
data_all = data_all.fillna("") # pour les valeurs nulles
data_all.head()
# Out:
#          Categorie1                  Categorie2  \
# 0      INFORMATIQUE  CONNECTIQUE - ALIMENTATION
# 1  TELEPHONIE - GPS        ACCESSOIRE TELEPHONE
# 2  TELEPHONIE - GPS        ACCESSOIRE TELEPHONE
# 3  TELEPHONIE - GPS        ACCESSOIRE TELEPHONE
# 4  TELEPHONIE - GPS        ACCESSOIRE TELEPHONE
#
#                           Categorie3  \
# 0                           BATTERIE
# 1  COQUE - BUMPER - FACADE TELEPHONE
# 2  COQUE - BUMPER - FACADE TELEPHONE
# 3  COQUE - BUMPER - FACADE TELEPHONE
# 4  COQUE - BUMPER - FACADE TELEPHONE
#
#                                          Description  \
# 0  Batterie Acer Aspire One 751H-52Yr - Li-Ion 11...
# 1  Coque rigide Bleu lagon pour ALCATEL OT / 6033...
# 2  Facades et coques CELLULAR LINE SHCKGALS 3 MIN...
# 3               Coque meteore TPU  LG Nexus 4 / E960
# 4  Coque souple Transparente pour LG G FLEX D959 ...
#
#                                             Libelle         Marque
# 0                Batterie Acer Aspire One 751H-52Yr         AUCUNE
# 1  Coque rigide Bleu lagon pour ALCATEL OT / 6033 …        MUZZANO
# 2  Facades et coques CELLULAR LINE SHCKGALS 3 MINIP  CELLULAR LINE
# 3              Coque meteore TPU  LG Nexus 4 / E960         AUCUNE
# 4  Coque souple Transparente pour LG G FLEX D959 m…        MUZZANO

# %%
def clean_line(l):
    l = l.lower()
    l=l.replace("751","")
    return l

# %%
data = data_all[["Categorie1","Description"]]
l = []
for cat, desc in data.values:
    l.append([cat, clean_line(desc)])

# %%
print(l)
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
data_lower = pd.DataFrame(l)
data_lower
# Out:
#                               0  \
# 0                  INFORMATIQUE
# 1              TELEPHONIE - GPS
# 2              TELEPHONIE - GPS
# 3              TELEPHONIE - GPS
# 4              TELEPHONIE - GPS
# ...                         ...
# 99995  DECO - LINGE - LUMINAIRE
# 99996                 LIBRAIRIE
# 99997          TELEPHONIE - GPS
# 99998  DECO - LINGE - LUMINAIRE
# 99999          TELEPHONIE - GPS
#
#                                                        1
# 0      batterie acer aspire one h-52yr - li-ion 11.1v...
# 1      coque rigide bleu lagon pour alcatel ot / 6033...
# 2      facades et coques cellular line shckgals 3 min...
# 3                   coque meteore tpu  lg nexus 4 / e960
# 4      coque souple transparente pour lg g flex d959 ...
# ...                                                  ...
# 99995  souvenirs de france - tour eiffel miniature 'p...
# 99996  fast track to waste-free manufacturing - john ...
# 99997  fitbag bonga girafe housse pochette pour télép...
# 99998                    grand tableau minnie t 50x50 cm
# 99999  étui en cuir avec emplacements pour carte & su...
#
# [100000 rows x 2 columns]

# %%
list_tokens = [x[1] for x in l ]
print(l[:2])
list_tokens[:2]
# Out:
# [['INFORMATIQUE', 'batterie acer aspire one h-52yr - li-ion 11.1v 5200mah, 54wh noir, compatible batterie… voir la présentation'], ['TELEPHONIE - GPS', 'coque rigide bleu lagon pour alcatel ot / 6033 motif drapeau liberia + 3 films - coque rigide ultra fine bleu lagon originale de muzzano au motif drapeau liberia pour alcatel … voir la présentation']]
# ['batterie acer aspire one h-52yr - li-ion 11.1v 5200mah, 54wh noir, compatible batterie… voir la présentation',
#  'coque rigide bleu lagon pour alcatel ot / 6033 motif drapeau liberia + 3 films - coque rigide ultra fine bleu lagon originale de muzzano au motif drapeau liberia pour alcatel … voir la présentation']

# %%
CV = CountVectorizer()
CV.fit(list_tokens)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
CV.vocabulary_
# Out:
# {'batterie': 26725,
#  'acer': 19455,
#  'aspire': 24077,
#  'one': 81455,
#  '52yr': 12790,
#  'li': 69673,
#  'ion': 64175,
#  '11': 1952,
#  '1v': 5648,
#  '5200mah': 12650,
#  '54wh': 13007,
#  'noir': 79870,
#  'compatible': 36882,
#  'voir': 111078,
#  'la': 68166,
#  'présentation': 88723,
#  'coque': 37992,
#  'rigide': 92893,
#  'bleu': 28408,
#  'lagon': 68372,
#  'pour': 87312,
#  'alcatel': 21044,
#  'ot': 82105,
#  '6033': 13937,
#  'motif': 76890,
#  'drapeau': 44311,
#  'liberia': 69724,
#  'films': 53150,
#  'ultra': 108205,
#  'fine': 53217,
#  'originale': 81896,
#  'de': 41304,
#  'muzzano': 77845,
#  'au': 24595,
#  'facades': 51846,
#  'et': 50289,
#  'coques': 38000,
#  'cellular': 33523,
#  'line': 70000,
#  'shckgals': 97891,
#  'minip': 75433,
#  'marque': 73230,
#  'agréée': 20540,
#  'samsungmobile': 95971,
#  'galaxy': 55962,
#  'minimatière': 75418,
#  'caoutchouc': 32284,
#  'souple': 99865,
#  'meteore': 74729,
#  'tpu': 106223,
#  'lg': 69631,
#  'nexus': 79470,
#  'e960': 47359,
#  'transparente': 106493,
#  'flex': 53649,
#  'd959': 40674,
#  'keep': 66555,
#  'calm': 31928,
#  'and': 22119,
#  'play': 86028,
#  'football': 54122,
#  'footbal': 54121,
#  'compatibilité': 36873,
#  'iphone': 64271,
#  '4s': 12144,
#  'caractéristiques': 32468,
#  'etuis': 50457,
#  'du': 44642,
#  'corps': 38161,
#  'entier': 49421,
#  'style': 101501,
#  'couleur': 38456,
#  'unie': 108399,
#  'blanc': 28247,
#  'rose': 93573,
#  'seiko': 97203,
#  'sfp599': 97725,
#  'hommes': 60991,
#  'montre': 76641,
#  'acheter': 19476,
#  'authentique': 24795,
#  'regarder': 91556,
#  'en': 48951,
#  'ligne': 69883,
#  'un': 108305,
#  'prix': 87966,
#  'réduit': 94416,
#  'infiniteshopping': 63290,
#  'pack': 82883,
#  'fruité': 55023,
#  'expert': 50984,
#  'titanium': 105374,
#  'mixte': 75694,
#  '8mg': 17162,
#  'ml': 75781,
#  '9mg': 18200,
#  'quel': 89745,
#  'dosage': 43976,
#  'mon': 76380,
#  'liquide': 70110,
#  'mg': 74888,
#  'sans': 96059,
#  'nicotine': 79584,
#  'ancien': 22091,
#  'fumeur': 55239,
#  'sevré': 97657,
#  'conseil': 37454,
#  'huile': 61433,
#  'rock': 93266,
#  'shox': 98105,
#  'deo': 41912,
#  'brunox': 30306,
#  'fourreaux': 54423,
#  'fourche': 54381,
#  '125': 2814,
#  'le': 69121,
#  'montage': 76565,
#  'des': 42013,
#  'pièces': 85700,
#  'détachées': 46823,
#  'doit': 43719,
#  'être': 116832,
#  'effectué': 47997,
#  'par': 83328,
#  'professionnel': 88165,
#  'votre': 111251,
#  'sécur': 102867,
#  'tube': 107347,
#  'tarozzi': 103855,
#  'kymco': 67774,
#  'citing': 35239,
#  '500': 12229,
#  '05': 595,
#  '07': 745,
#  'ø40': 116927,
#  '613mm': 14185,
#  'cable': 31618,
#  'emb': 48668,
#  'kawasaki': 66444,
#  'moto': 76912,
#  'diabolos': 42563,
#  'bequille': 27357,
#  'm6': 71969,
#  'chrome': 34875,
#  'pro': 87979,
#  'accessoires': 19307,
#  'reparation': 92044,
#  'garage': 56146,
#  'canette': 32186,
#  'bobines': 28736,
#  'matériau': 73681,
#  'alliage': 21282,
#  'support': 102051,
#  'léger': 71525,
#  'kit': 67021,
#  'gros': 58360,
#  'freins': 54792,
#  'sport': 100353,
#  'pistons': 85632,
#  'ford': 54161,
#  'max': 73805,
#  '114': 2237,
#  '_fixing_noir_356x32': 18328,
#  'bleue': 28428,
#  'suede': 101744,
#  'collecteurs': 36390,
#  'echappement': 47621,
#  'honda': 61018,
#  '650': 14560,
#  'cx': 40073,
#  'compaq': 36834,
#  'presario': 87717,
#  'v6402au': 109170,
#  '4400mah': 11180,
#  '10': 1035,
#  '8v': 17204,
#  'ioncaracté': 64185,
#  'debardeur': 41376,
#  'femme': 52592,
#  'superman': 101986,
#  'or': 81671,
#  'rouge': 93727,
#  '6030': 13931,
#  'follow': 54004,
#  'buddha': 30526,
#  'playmobil': 86054,
#  'superset': 102010,
#  'aire': 20706,
#  'stockage': 101169,
#  'chantier': 34046,
#  '4135véritable': 10754,
#  'avec': 25050,
#  'grilles': 58228,
#  'système': 102756,
#  'fermeture': 52705,
#  'matéri': 73678,
#  'teo': 104481,
#  'aux': 24948,
#  'éditions': 116097,
#  'emmanuel': 48825,
#  'proust': 88503,
#  'averatec': 25084,
#  '5500': 13016,
#  'ioncaractéristiques': 64190,
#  'techniques': 104148,
#  'keenen': 66554,
#  'ivory': 64599,
#  'wayans': 112171,
#  'shannon': 97846,
#  'elizabeth': 48515,
#  'carmen': 32681,
#  'electra': 48365,
#  'lampe': 68528,
#  'usb': 108670,
#  'packard': 82892,
#  'bell': 27210,
#  'easynote': 47468,
#  'enlg71bm': 49283,
#  'bureau': 30682,
#  'led': 69223,
#  'alimentée': 21187,
#  'il': 62565,
#  'suffit': 101761,
#  'brancher': 29748,
#  'dans': 40905,
#  'port': 86993,
#  'ordinateur': 81761,
#  'ou': 82137,
#  'po': 86353,
#  'pantalon': 83210,
#  'baudoin': 26762,
#  'ditla': 43348,
#  'homme': 60976,
#  'composition': 37000,
#  'coton': 38332,
#  'sony': 99648,
#  'xperia': 113984,
#  'typo': 107773,
#  'islam': 64432,
#  'gris': 58280,
#  '100': 1036,
#  'made': 72245,
#  'in': 62929,
#  'france': 54616,
#  'cette': 33757,
#  'mettra': 74772,
#  'valeur': 109359,
#  'smartphone': 99038,
#  'vinyle': 110549,
#  'autocollant': 24829,
#  'pink': 85506,
#  'floyd': 53818,
#  'dark': 40966,
#  'side': 98175,
#  'of': 81124,
#  'the': 104778,
#  'moon': 76683,
#  'hauteur': 59875,
#  'cm': 35864,
#  '02': 363,
#  'lit': 70175,
#  'mijou': 75180,
#  '48': 11751,
#  '37': 9765,
#  'pouces': 87255,
#  'crème': 39479,
#  'imitation': 62705,
#  'fourrure': 54429,
#  'agneau': 20453,
#  'couverture': 38735,
#  'polyester': 86711,
#  'rembourrage': 91808,
#  'mousse': 77082,
#  'remplissage': 91898,
#  'fibres': 52963,
#  'polyestercoloris': 86722,
#  'dimensions': 42913,
#  'bague': 25962,
#  'stretchme': 101367,
#  'ever': 50635,
#  'blue': 28576,
#  'sapphires': 96119,
#  'arge': 23393,
#  'argent': 23396,
#  'massif': 73463,
#  '925': 17648,
#  'serti': 97551,
#  'saphirs': 96110,
#  'bleus': 28450,
#  'poids': 86427,
#  'chargeur': 34125,
#  'hp': 61247,
#  'deskjet': 42143,
#  '450': 11338,
#  'cars': 32801,
#  'poster': 87184,
#  'reproduction': 92133,
#  'sur': 102088,
#  'toile': 105675,
#  'tendue': 104428,
#  'châssis': 34978,
#  'mcqueen': 74121,
#  '95': 17856,
#  '30': 8358,
#  '40': 10320,
#  'clé': 35842,
#  'polygonale': 86758,
#  'double': 44036,
#  'contre': 37723,
#  'coudée': 38434,
#  '20x22': 6235,
#  '180': 4764,
#  'unior': 108428,
#  'a3': 18678,
#  'my': 77940,
#  'little': 70221,
#  'pony': 86922,
#  'blues': 28591,
#  'brothers': 30213,
#  'soul': 99801,
#  'mares': 73053,
#  'by': 30884,
#  'filipinoninja95': 53115,
#  '29': 7950,
#  '42': 10861,
#  'papier': 83280,
#  'mat': 73512,
#  '160gr': 4272,
#  'envoyés': 49612,
#  'roulés': 93826,
#  'artiste': 23826,
#  'créateur': 39488,
#  'lot': 70757,
#  'toiles': 105678,
#  'imprimées': 62885,
#  'harmonie': 59761,
#  'saint': 95783,
#  'seiya': 97215,
#  'next': 79467,
#  'dimension': 42909,
#  'tome': 105764,
#  'monographies': 76500,
#  'lanière': 68631,
#  'tour': 106092,
#  'cou': 38404,
#  'cigarette': 35066,
#  'électronique': 116251,
#  'logo': 70508,
#  'disponible': 43225,
#  'couleurs': 38489,
#  'spécifier': 100492,
#  'lors': 70736,
#  'commande': 36704,
#  'commentaire': 36731,
#  'pratique': 87607,
#  'otterbox': 82132,
#  'commuter': 36793,
#  'series': 97494,
#  'étui': 116743,
#  'téléphone': 107866,
#  'cellulaire': 33521,
#  'silicone': 98346,
#  'vert': 110059,
#  'apple': 22882,
#  '3g': 10170,
#  '3gs': 10181,
#  'description': 42063,
#  'produit': 88111,
#  'housse': 61225,
#  'etui': 50453,
#  'clapet': 35406,
#  'rabat': 90208,
#  'i9003': 61934,
#  'samsung': 95969,
#  'très': 107170,
#  'bonne': 29013,
#  'qualité': 89629,
#  'protège': 88474,
#  'les': 69452,
#  'rayures': 90899,
#  'salissures': 95864,
#  'chocs': 34740,
#  'ainsi': 20680,
#  'qu': 89577,
#  'nixon': 79731,
#  'unit': 108472,
#  'black': 28182,
#  'forme': 54228,
#  'ronde': 93469,
#  'design': 42100,
#  'futuriste': 55365,
#  'fois': 53960,
#  'urbain': 108590,
#  'display': 43208,
#  'doté': 44028,
#  'boutons': 29505,
#  'action': 19628,
#  'promonto': 88308,
#  'dentelle': 41880,
#  'leavers': 69171,
#  'calais': 31819,
#  'microfibre': 75051,
#  'italienne': 64542,
#  'exprimez': 51064,
#  'féminité': 55560,
#  'sensualité': 97394,
#  'légère': 71548,
#  'florale': 53746,
#  'motifs': 76894,
#  'éventails': 116783,
#  'ornée': 81971,
#  'déli': 46527,
#  'ryobi': 94266,
#  'batteries': 26727,
#  '18v': 5049,
#  'bpl18152': 29646,
#  '2x': 8282,
#  'bpl': 29643,
#  '18152n': 4853,
#  'lithium': 70195,
#  '18': 4763,
#  'volts': 111171,
#  'bloc': 28505,
#  'jonction': 65497,
#  'fusible': 55326,
#  'contenu': 37646,
#  '20': 5720,
#  'pc': 84039,
#  'weidmüller': 112351,
#  'saks': 95812,
#  '5x30': 13764,
#  '500v': 12300,
#  '0297520000': 431,
#  'blocs': 28517,
#  'série': 102982,
#  'sak': 95807,
#  'sont': 99645,
#  'proposés': 88361,
#  'versions': 110050,
#  'molette': 76318,
#  'serrage': 97529,
#  'collier': 36446,
#  'r39302800': 90034,
#  'ppe': 87508,
#  'ultraflow': 108228,
#  'qualite': 89623,
#  'neuf': 79377,
#  'haute': 59868,
#  'donne': 43826,
#  'prime': 87853,
#  'tactile': 103511,
#  'look': 70674,
#  'mode': 76088,
#  'installation': 63646,
#  'facile': 51872,
#  'comme': 36719,
#  'images': 62657,
#  'montrent': 76645,
#  'peut': 84901,
#  'shirt': 98007,
#  'mur': 77681,
#  'escalade': 50012,
#  'climbing': 35653,
#  'wall': 111968,
#  'pictogramme': 85323,
#  'print': 87904,
#  'lavable': 68918,
#  'machine': 72185,
#  'stickers': 101102,
#  'porte': 87019,
#  'trompe': 106948,
#  'oeil': 81102,
#  'déco': 46235,
#  'illuminée': 62600,
#  'réf': 94426,
#  '829': 16563,
#  '73x204cm': 15620,
#  'vous': 111268,
#  'pouvez': 87405,
#  'poser': 87116,
#  'nos': 80145,
#  'tout': 106157,
#  'type': 107740,
#  'surface': 102119,
#  'lisse': 70153,
#  'placard': 85813,
#  'voiture': 111087,
#  'first': 53342,
#  'hundred': 61512,
#  'words': 113081,
#  'portuguese': 87091,
#  'mairi': 72501,
#  'mackinnon': 72208,
#  'verrou': 110012,
#  'sureté': 102115,
#  '136': 3380,
#  '3060': 8571,
#  'coffre': 36258,
#  'gâche': 59024,
#  'acier': 19506,
#  'embouti': 48733,
#  'verni': 109976,
#  'pêne': 89417,
#  'saillie': 95772,
#  'réglable': 94504,
#  'mm': 75850,
#  'démontage': 46588,
#  'cylindre': 40164,
#  'goupilles': 57671,
#  'diamètre': 42639,
#  '23': 6833,
#  'longueur': 70657,
#  '45': 11337,
#  'uriage': 108619,
#  'aquaprécis': 23091,
#  'confort': 37293,
#  'minéraux': 75516,
#  'eau': 47503,
#  'thermale': 104851,
#  'pouvoir': 87407,
#  'exceptionnel': 50824,
#  'associés': 24169,
#  'osmolytes': 82078,
#  'organique': 81816,
#  'soin': 99411,
#  'aquapréc': 23090,
#  'pierres': 85368,
#  'zirconium': 115389,
#  'neuve': 79411,
#  'largeur': 68740,
#  '8cm': 17118,
#  'emballage': 48674,
#  'cadeau': 31685,
#  'vente': 109854,
#  'garantie': 56152,
#  'bijouterie': 27824,
#  'joaillerie': 65375,
#  'singes': 98512,
#  'tender': 104416,
#  'feeling': 52528,
#  'anup': 22661,
#  'manoj': 72870,
#  'shah': 97802,
#  '50': 12228,
#  'pavilion': 83949,
#  'dv3t': 45309,
#  '2000': 5722,
#  '7800mah': 15984,
#  '86wh': 16882,
#  '204mm': 6074,
#  '57mm': 13340,
#  '40mm': 10592,
#  'oreal': 81775,
#  'fond': 54057,
#  'teint': 104242,
#  'poudre': 87265,
#  'minéral': 75503,
#  'accord': 19351,
#  'parfait': 83468,
#  'sable': 95635,
#  'doré': 43960,
#  'descriptif': 42054,
#  'minérale': 75507,
#  'couvrance': 38740,
#  'révolutionnent': 94839,
#  'bienfa': 27774,
#  'toshiba': 106003,
#  'satellite': 96200,
#  'a205': 18632,
#  's5831': 95381,
#  'parfaitement': 83478,
#  'mitaine': 75634,
#  'résille': 94688,
#  'bobine': 28735,
#  'cordon': 38077,
#  'ciré': 35197,
#  'fermoir': 52720,
#  'aucunmatière': 24630,
#  'textile': 104666,
#  'thème': 105073,
#  'adulte': 20093,
#  'enfant': 49150,
#  'indémodable': 63223,
#  'filtre': 53169,
#  'metal': 74701,
#  'antigraisse': 22564,
#  'x1': 113385,
#  'ad546be11': 19720,
#  'ad546we1': 19721,
#  'ad249xe1': 19709,
#  'gs602b': 58547,
#  'shd23xf21': 97893,
#  'shd23xf22': 97894,
#  'shd2': 97892,
#  'compat': 36863,
#  's5830': 95379,
#  'ballon': 26141,
#  'foot': 54118,
#  'allemagne': 21251,
#  'sams': 95962,
#  'guess': 58762,
#  'u10571l1': 107943,
#  'womens': 113026,
#  'ballerina': 26132,
#  'ampoule': 21899,
#  'osram': 82088,
#  'silverstar': 98401,
#  'h4': 59285,
#  'jusqu': 65837,
#  '60': 13806,
#  'lumière': 71262,
#  'plus': 86231,
#  'beaucoup': 27014,
#  'stabilité': 100780,
#  'faisceau': 51964,
#  'lumineux': 71239,
#  'est': 50211,
#  'long': 70589,
#  'mètres': 78090,
#  'moderne': 76142,
#  'adapté': 19777,
#  'plupar': 86226,
#  'v3609tu': 109060,
#  'appareil': 22832,
#  'rear': 91090,
#  'bmw': 28679,
#  'f30': 51471,
#  '328i': 9099,
#  '120': 2505,
#  'disque': 43254,
#  '380x32': 9915,
#  'fixation': 53406,
#  'floating': 53707,
#  'etriers': 50432,
#  'frein': 54787,
#  'main': 72464,
#  'origine': 81906,
#  'ye': 114354,
#  'platine': 86007,
#  'spa': 100011,
#  '800': 16228,
#  'sb': 96403,
#  'complète': 36948,
#  'blower': 28565,
#  'procopi': 88065,
#  'cuvée': 40011,
#  'springtime': 100418,
#  'maison': 72507,
#  'pommery': 86851,
#  'champagne': 33953,
#  'rosé': 93664,
#  'charmeur': 34170,
#  'acidulé': 19501,
#  'une': 108357,
#  'déguster': 46503,
#  'belle': 27217,
#  'journée': 65613,
#  'printemps': 87913,
#  'vin': 110497,
#  'friand': 54839,
#  'envoûtant': 49613,
#  'panasonic': 83133,
#  'sdr': 96962,
#  's15': 94995,
#  '6v': 15116,
#  '1000mah': 1074,
#  '6wh': 15124,
#  '4mm': 12112,
#  '36': 9620,
#  '5mm': 13667,
#  '18g': 5025,
#  'tous': 106152,
#  'ar': 23147,
#  'noire': 79911,
#  'huawei': 61391,
#  'ascend': 23949,
#  'p2': 82517,
#  'quebec': 89736,
#  'master': 73490,
#  '7w': 16192,
#  'dimmable': 42937,
#  'eq': 49773,
#  '50w': 12482,
#  'offre': 81170,
#  'réduction': 94407,
#  'produits': 88138,
#  'achetés': 19480,
#  '15': 3869,
#  'envie': 49567,
#  'connaitre': 37376,
#  'différentes': 42811,
#  'technologies': 104170,
#  'cliquez': 35698,
#  '3m': 10206,
#  'replacement': 92072,
#  'lamp': 68523,
#  'x95w': 113735,
#  'projecteur': 88246,
#  'x95': 113733,
#  'x95i': 113734,
#  'digital': 42852,
#  'projector': 88251,
#  'pédagogies': 89332,
#  'développement': 46906,
#  'edition': 47875,
#  '2011': 5945,
#  'tissot': 105350,
#  'race': 90271,
#  't0484172705704': 103050,
#  'gregori': 58136,
#  'vigot': 110430,
#  'dks': 43470,
#  'sublime': 101628,
#  'qui': 89787,
#  'possède': 87171,
#  'découpe': 46334,
#  'vitre': 110841,
#  'protéger': 88488,
#  'écran': 116056,
#  'voyant': 111291,
#  'heure': 60468,
#  'date': 41042,
#  'pra': 87566,
#  'countryman': 38539,
#  'r60': 90112,
#  '09': 885,
#  'tapis': 103798,
#  'velours': 109783,
#  'clip': 35671,
#  'mini': 75377,
#  'année': 22382,
#  'fabrication': 51812,
#  'partir': 83641,
#  '2010': 5919,
#  'dynamisez': 46036,
#  'coté': 38399,
#  'classique': 35475,
#  'salon': 95887,
#  'grâce': 58490,
#  'table': 103462,
#  'oreste': 81800,
#  'son': 99590,
#  'rangement': 90642,
#  'central': 33596,
#  'atout': 24453,
#  'si': 98139,
#  'souhaitez': 99795,
#  'optimiser': 81622,
#  'espace': 50097,
#  'dure': 44890,
#  'case': 32905,
#  'transparent': 106488,
#  'cheri': 34460,
#  'fais': 51961,
#  'déclaration': 46210,
#  'visuelle': 110789,
#  'notre': 80190,
#  'hardcase': 59711,
#  'unis': 108458,
#  'affiné': 20281,
#  'parfaite': 83471,
#  'protection': 88431,
#  'cacher': 31662,
#  'château': 34984,
#  'poitevin': 86505,
#  '1992': 5292,
#  'canon': 32230,
#  'elura': 48603,
#  '10mc': 1882,
#  '4v': 12172,
#  '3000mah': 8377,
#  '22': 6579,
#  '2wh': 8279,
#  '55': 13014,
#  '2mm': 8206,
#  '3mm': 10212,
#  '38': 9899,
#  '7mm': 16158,
#  '149g': 3794,
#  'rk': 93090,
#  '85': 16713,
#  'leurre': 69536,
#  'crank': 39028,
#  'bait': 26013,
#  'crochets': 39279,
#  'ce': 33371,
#  'populaire': 86957,
#  'pêche': 89410,
#  'dur': 44848,
#  'el': 48263,
#  'salvador': 95909,
#  'app': 22815,
#  'prybar': 88572,
#  'lucky': 71145,
#  'guidon': 58801,
#  'trotinette': 106996,
#  'material': 73553,
#  '4130': 10745,
#  'chromolydowntube': 34890,
#  'steertube': 101009,
#  'crossbar': 39364,
#  'backsweep': 25888,
#  'weight': 112352,
#  'lb': 69002,
#  'kg': 66725,
#  'finish': 53244,
#  'dv6064ea': 45441,
#  '47wh': 11742,
#  'cellules': 33525,
#  'photo': 85148,
#  'référence': 94472,
#  'seulement': 97629,
#  'andré': 22164,
#  'brincourt': 30016,
#  'lgf': 69648,
#  'charm': 34158,
#  'chauve': 34357,
#  'souris': 99888,
#  'so': 99271,
#  'bijou': 27821,
#  'orné': 81970,
#  'cristaux': 39240,
#  'bohème': 28819,
#  'plaquage': 85923,
#  'tenue': 104473,
#  'garanti': 56150,
#  'nickel': 79554,
#  'mousqueton': 77068,
#  'mugs': 77457,
#  'alchemy': 21051,
#  'king': 66956,
#  '13': 3088,
#  'taille': 103575,
#  'unique': 108434,
#  'perche': 84492,
#  'telescopique': 104306,
#  'security': 97125,
#  'lock': 70446,
#  '3x2m': 10286,
#  's4': 95182,
#  'i9190': 61957,
#  'i9195': 61959,
#  'pochette': 86375,
#  'gel': 56546,
#  'stylet': 101527,
#  'brassard': 29786,
#  'ga': 55842,
#  'c710el': 31455,
#  'capacité': 32316,
#  '8800mah': 16964,
#  'yuga': 114576,
#  'route': 93850,
#  '66': 14705,
#  'protect': 88422,
#  'sel': 97222,
#  'guérande': 58939,
#  'épices': 116449,
#  'verrine': 110010,
#  '150': 3870,
#  'gr': 57785,
#  'ingrédients': 63377,
#  'kashmiri': 66382,
#  'masala': 73395,
#  'f2299a': 51427,
#  '14': 3543,
#  '4000mah': 10335,
#  'fonce': 54009,
#  'bequilles': 27358,
#  'laterales': 68829,
#  'yamaha': 114283,
#  'dtr': 44630,
#  '2001': 5757,
#  '2002': 5770,
#  'livraison': 70267,
#  'possible': 87165,
#  'sous': 99894,
#  '48h': 11882,
#  'soigné': 99405,
#  'expédition': 51073,
#  'quotidie': 89885,
#  'collectif': 36396,
#  'eska': 50077,
#  'boucles': 29292,
#  'oreille': 81785,
#  'thierry': 104942,
#  'mugler': 77455,
#  't32225z': 103218,
#  'inoxydable': 63511,
#  'collection': 36402,
#  'serties': 97554,
#  'oxydes': 82393,
#  'bottes': 29239,
#  'bi': 27668,
#  'matière': 73626,
#  'talons': 103686,
#  'zaza': 114918,
#  'pata': 83798,
#  'bleues': 28432,
#  'empiècement': 48881,
#  'motard': 76870,
#  'devant': 42316,
#  'tige': 105166,
#  'suédine': 102312,
#  'sangle': 96038,
#  'chaîne': 34374,
#  'décor': 46297,
#  'ktm': 67607,
#  'exc': 50785,
#  '250': 7259,
#  '12': 2504,
#  'chaine': 33868,
#  'tsubaki': 107287,
#  '485343': 11852,
#  'chlorure': 34707,
#  'magnesium': 72352,
#  'paquet': 83319,
#  'grs': 58421,
#  'complément': 36958,
#  'alimentaire': 21172,
#  'santé': 96086,
#  'magnésium': 72390,
#  'véritable': 111608,
#  'remède': 91910,
#  'miracle': 75532,
#  'chaque': 34088,
#  'famille': 52033,
#  'devrait': 42407,
#  'avoir': 25160,
#  'permanen': 84632,
#  'perforée': 84586,
#  'cd': 33310,
#  'dvd': 45809,
#  'a6': 18788,
#  'pp': 87494,
#  'hetzel': 60462,
#  'droite': 44437,
#  'classeur': 35458,
#  'satiné': 96215,
#  'perfora': 84552,
#  'oreillette': 81794,
#  'bluetooth': 28598,
#  'hm1200': 60791,
#  'sgh': 97753,
#  'i600': 61884,
#  's5': 95244,
#  'premiumcoque': 87683,
#  'blanche': 28288,
#  'mixed': 75683,
#  'up': 108562,
#  'points': 86468,
#  'vues': 111476,
#  'premiumcase': 87682,
#  'ton': 105787,
#  'deviendra': 42374,
#  'point': 86453,
#  'mire': 75547,
#  'z1': 114637,
#  'compact': 36803,
#  'steine': 101025,
#  'amortisseur': 21818,
#  'tablettes': 103471,
#  'flexible': 53659,
#  'set': 97608,
#  'maquillage': 72961,
#  'diable': 42557,
#  'composé': 37013,
#  'godets': 57397,
#  'déguisement': 46491,
#  'favori': 52280,
#  'que': 89734,
#  'pinceau': 85481,
#  'attention': 24522,
#  'ne': 79145,
#  'meuble': 74786,
#  'cuisine': 39791,
#  'bas': 26555,
#  '15cm': 4154,
#  'accessoire': 19305,
#  'cookie': 37851,
#  'facade': 51845,
#  'panneau': 83173,
#  'agglomere': 20422,
#  'epaisseur': 49683,
#  '9cm': 18167,
#  'recouvert': 91266,
#  'film': 53144,
#  'stratifie': 101314,
#  'decor': 41477,
#  'bois': 28833,
#  'clair': 35367,
#  'tampons': 103723,
#  'crash': 39059,
#  'pad': 82908,
#  'lsl': 70993,
#  'orange': 81685,
#  'xjr': 113909,
#  '1200': 2506,
#  '1995': 5301,
#  '1998': 5310,
#  'roulettes': 93810,
#  ...}

# %%
features = CV.transform(list_tokens[:2])
features
# Out:
# <2x116985 sparse matrix of type '<class 'numpy.int64'>'
# 	with 37 stored elements in Compressed Sparse Row format>

# %%
features.getrow(0).indices
# Out:
# array([  1952,   5648,  12650,  12790,  13007,  19455,  24077,  26725,
#         36882,  64175,  68166,  69673,  79870,  81455,  88723, 111078],
#       dtype=int32)

# %%
[(k,v) for k,v in CV.vocabulary_.items() if v ==1952]
# Out:
# [('11', 1952)]

# %%
def cleaning(voca) :

    #print("Number of unique words in the total vocabulary :" ,len(set(voca.split(" "))))
    
    #STEP 1 : removing special characters and put the vocabulary in lower
    cleaned_voc = voca
    cleaned_voc = cleaned_voc.lower()
    cleaned_voc = cleaned_voc.replace(u'\u2026','.')
    cleaned_voc = cleaned_voc.replace(u'\u00a0',' ')
    #print("Number of unique words in the total vocabulary, after the FIRST step of cleaning :" ,len(set(cleaned_voc.split(" "))))
    
    #STEP 2 : takes off some punctuation
    cleaned_voc = unicodedata.normalize('NFD', cleaned_voc).encode('ascii', 'ignore').decode("utf-8")
    #print("Number of unique words in the total vocabulary, after the SECOND step of cleaning :" ,len(set(cleaned_voc.split(" "))))
    
    #STEP 3 : keeps only alphabet letters
    cleaned_voc = re.sub('[^a-z_]', ' ', cleaned_voc)
    #print("Number of unique words in the total vocabulary, after the THIRD step of cleaning :" ,len(set(cleaned_voc.split(" "))))
    
    
    ## Words to delete from the descriptions
    ## Using NLTK
    stopwords = nltk.corpus.stopwords.words('french') 
    #stopwords[:10]
    
    #removing what in the stopwords ??? punctuation ?
    stopwords = [unicodedata.normalize('NFD', sw).encode('ascii', 'ignore').decode("utf-8") for sw in stopwords]
    stopwords += ["voir"]
    stopwords += ["presentation"]
    #stopwords[:10]

    
    #creation of tokens and removing the french stop word & words with less than 2 letters
    tokens = [w for w in cleaned_voc.split(" ") if (len(w)>2) and (w not in stopwords)]
    removed_words = [w for w in cleaned_voc.split(" ") if (len(w)<2) or (w in stopwords)]
    
      
    #removed_words and examples of some tokens
    #print("\n Removed words :")
    #print(set(removed_words), '\n')

    #print("Some tokens :")
    #print(tokens[:100])
    
    
    ## Stemming function to get roots of words (racines des mots)
    stemmer=nltk.stem.SnowballStemmer('french')
    tokens_stem = [stemmer.stem(token) for token in tokens]
    #print(tokens_stem[:10])
    
    voca_cleaned = ""
    
    for t in tokens_stem :
        voca_cleaned += t
        voca_cleaned += " "
    
    #print("Number of tokens we have after the cleaning :" ,len(set(tokens_stem)), "\n \n")
    
    return voca_cleaned

# %%
data = data_all[["Categorie1","Description"]]
l = []
#print(data.values[:2])
#d = set(cleaning(data.values[0,1]))
#print(d)
for cat, desc in data.values[:2]:
    l.append([cat, cleaning(desc)]) #pb pendant le cleaning car ajoute liste

# %%
data_lower = pd.DataFrame(l) 
data_lower
# Out:
#                   0                                                  1
# 0      INFORMATIQUE  batter acer aspir one ion mah noir compatibl b...
# 1  TELEPHONIE - GPS  coqu rigid bleu lagon alcatel motif drapeau li...

# %%
list_tokens = [x[1] for x in l]
CV = CountVectorizer()
CV.fit(list_tokens)
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#                 dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#                 lowercase=True, max_df=1.0, max_features=None, min_df=1,
#                 ngram_range=(1, 1), preprocessor=None, stop_words=None,
#                 strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#                 tokenizer=None, vocabulary=None)

# %%
" ".join(["a","b"])
# Out:
# 'a b'
